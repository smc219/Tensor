# %% [markdown]
# <a href="https://colab.research.google.com/github/hochaeAidl/ai-middle-course/blob/master/02_05_file_handling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 실습 2-0-0. Colab에서 Google Drive 활용 실습

# %% [markdown]
# ## Google Drive Mount

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# ### Basic commands
#   - Shell commands
#   - with '!'

# %%
# pwd: print working directory
# !pwd
# !ls

# %% [markdown]
# - How about shell commad 'cd', change directory?

# %%
# !cd drive/
print ('!cd is done')
# !pwd

# %% [markdown]
# ## 왜 바뀌지 않을까?

# %% [markdown]
# ### -- Shell command들은 temporal subshell에서 수행되기 때문이다.
# ### -- 방법은? Magicshell을 사용한다.
# ### ---> `%automagic`

# %% [markdown]
# ## Shell-related Magic commands
#   - with '%'

# %%
# cd: change directory
# %cd /content/drive/
# !pwd

# %% [markdown]
# ## `%automagic` ?

# %%
cd ..

# %%
ls -al

# %%
ls

# %%
# %automagic on

# %% [markdown]
# - ## [IPython and Shell Commands](https://colab.research.google.com/github/jakevdp/PythonDataScienceHandbook/blob/master/notebooks/01.05-IPython-And-Shell-Commands.ipynb#scrollTo=-XN8jw7DNL51)
